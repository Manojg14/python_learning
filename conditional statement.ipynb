# %% [markdown]
# ### IF ELSE Condition

# %%
if (True):
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
a = 10
print("Quo:",a/2)
# Out:
# Quo: 5.0

# %%
a = 10
print("Rem:", a%2)
# Out:
# Rem: 0

# %% [markdown]
# ### Practice Q/A

# %% [raw]
# 1) get i/p for variable Meghna, if Meghna == died Print "Suriya weds Priya else Print "Suriya weds Meghna

# %%
Meghna = "died"
if Meghna == 'died':
    print("Surya weds Priya")
else:
    print("Surya weds Meghna")
# Out:
# Surya weds Priya

# %% [raw]
# 2) Get i/p variable Mark. If Mark>35 Pass else Fail. user Input

# %% [raw]
# Mark = int(input("enter Mark:"))
# if Mark > 35:
#     print('Pass')
# else:
#     print('Fail')

# %% [raw]
# 3) Get i/p for Variable income. if income is > er than 7000 scholarship is avaliable.else not eligible for scholarship

# %%
income = int(input("enter your income:"))
if Mark > 7000:
    print('not eligible for scholarship')
else:
    print('scholarship is avaliable')
# Out:
# enter your income: 6000
# scholarship is avaliable

# %% [raw]
# 4) Get input for a number and check if it is divisible by both 3 and 5 or not.if yes print num is divisible by both 3 and 5.else print the num is not divisible by 3 and 5

# %%
number = int(input("enter number:"))
if number % 3 == 0 and number % 5 == 0:
    print("num is divisible by both 3 and 5")
else:
    print("num is not divisible by 3 and 5")
# Out:
# enter number: 25
# num is not divisible by 3 and 5

# %% [raw]
# 5) Get number to check odd or even

# %%
number = int(input("enter number:"))
if number % 2 == 0 :
    print("Number is Even Number")
else:
    print("Number is Odd Number")
# Out:
# enter number: 22
# Number is Even Number

# %% [raw]
# 6) Check the Score wise separation

# %%
score = int(input("enter your score:"))
if score >= 70:
    print("Good Student")
elif 70 > score >= 35:
    print("Average Student")
else:
    print("Poor Student")
# Out:
# enter your score: 77
# Good Student

# %% [markdown]
# ### Mini Calculator

# %% [markdown]
# a = int(input("enter a:"))
# b = int(input("enter b:"))
# user = input("Enter your choice sum/sub/mul/div:")
# if user == 'sum':
#     print(f"Sum of Values is {a+b}")
# elif user == 'sub':
#     print(f"Subtraction of Values is {a-b}")
# elif user == 'mul':
#     print(f"Multiply of Values is {a*b}")
# elif user == 'div':
#     print(f"Division of Values is {a/b}")
# else:
#     print("enter valid option")

# %% [raw]
# 8) get a input for score percentage. only percentage >er than 70 means,get user input name,department and location.then print your are eligible . if not your not eligible

# %%
score = int(input("enter your score:"))
if score > 70:
    print ("You are Eligible")
    name = input("enter your name:")
    department = input("enter your department:")
    location = input("enter your location:")
else:
    print("You are not Eligible")
# Out:
# enter your score: 77
# You are Eligible
# enter your name: Man0j
# enter your department: Ece
# enter your location: Namakkal

# %% [raw]
# 9) get i/p salary and age, if salary above equal to 20000 or age above equal to 25 means eligible for bank loan,get them input loan amount required .not eligible for bank loan
# if loan amount less than are equal to 50000 means you are eligible for loan,if it is greater than 50000 print Maxmium loan amount is 50000

# %%
salary = int(input("enter your salary:"))
age = int(input("enter your age:"))
if salary >= 20000 or age >= 25:
    loan = int(input("Enter your Required Loan Amount:"))
    if loan <= 50000:
        print("your are eligible for bank loan")
    else:
        print("Maximum Loan Amount is 50000")
else:
    print("your are not eligible for bank loan")
# Out:
# enter your salary: 25000
# enter your age: 22
# Enter your Required Loan Amount: 45000
# your are eligible for bank loan

# %% [raw]
# 10) get i/p for 5 subjects marks. add all for it, and find average.if average mark is less than 35.print "additional class is required" else "you are good to go"

# %%
English = int(input("Enter your english Mark:"))
Tamil = int(input("Enter your tamil Mark:"))
Maths = int(input("Enter your maths Mark:"))
Science = int(input("Enter your science Mark:"))
Social = int(input("Enter your social Mark:"))
avg = (English + Tamil + Maths + Science + Social) / 5
print(f"Your Average Mark is {avg}")
if avg < 35:
    print("Additional Class is Required")
else:
    print("You are Good to go")
# Out:
# Enter your english Mark: 25
# Enter your tamil Mark: 34
# Enter your maths Mark: 56
# Enter your science Mark: 32
# Enter your social Mark: 21
# Your Average Mark is 33.6
# Additional Class is Required
