# %% [markdown]
# ## Two Hash Letter Size

# %% [markdown]
# ### Three Hash Letter Size

# %% [markdown]
# ### Variable

# %%
a = 10

# %% [markdown]
# ### Data type

# %%
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
b = 'Manoj'
print(type(b))
# Out:
# <class 'str'>

# %% [markdown]
# ### Casting

# %%
a = "10"
b = "20"
print(a+b)
# Out:
# 1020

# %%
a = int("10")
b = int("20")
print(a+b)
# Out:
# 30

# %% [markdown]
# ### User Get Input

# %%
a = input("enter a")
b = input("enter b")
c = a + b
print(c)
# Out:
# enter a 10
# enter b 20
# 1020

# %%
a = int(input("enter a"))
b = int(input("enter b"))
c = a + b
print(c)
# Out:
# enter a 10
# enter b 20
# 30

# %% [markdown]
# ### Practice Q/A

# %% [raw]
# 1) Get an Input for Variable Name and age . Print it

# %%
name = input("Enter Your Name:")
age = int(input("Enter Your Age:"))
print(f"My name is {name}")
print(f"My age is {age}")
# Out:
# Enter Your Name: Man0j
# Enter Your Age: 22
# My name is Man0j
# My age is 22

# %% [raw]
# 2) Get integer input for variable a,b,c.
# Multiply all 3 Variable (a * b * c)
# add all 3 variable (a + b + c)
# Divide multiplied by added values. print it

# %%
a = int(input("enter a"))
b = int(input("enter b"))
c = int(input("enter c"))
mul = a * b * c
add = a + b + c
div = mul/add
print(f"Multiplied Values {mul}")
print(f"Add Values {add}")
print(f"Divied Values {div}")
# Out:
# enter a 10
# enter b 20
# enter c 30
# Multiplied Values 6000
# Add Values 60
# Divied Values 100.0

# %% [raw]
# 3) Get i/p for variable name,score, department
# get score for 100;
# divide 100/10

# %% [raw]
# name = input("enter name")
# score = int(input("enter score"))
# div = score/10
# department = input("enter department")
# print(f"Name:{name}")
# print(f"Score:{div}/10")
# print(f"Department:{department}")
